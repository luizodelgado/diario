# %%
import pandas as pd
import matplotlib.pyplot as plt

db = pd.read_csv('./database/jobs-and-salaries-in-data-science/jobs_in_data.csv')

salario = sum(db.salary)

plt.plot(db.work_year, db.salary)

plt.show()

# print([db.work_year, db.salary])

# %%
import pandas as pd
import matplotlib.pyplot as plt

db = pd.read_csv('./database/jobs-and-salaries-in-data-science/jobs_in_data.csv')

tabela_resumida = db.groupby('work_year')['salary'].sum().reset_index()

plt.plot(tabela_resumida.work_year, tabela_resumida.salary)

print(tabela_resumida)

plt.show()
# Out:
#    work_year      salary
# 0       2020     7577809
# 1       2021    21531519
# 2       2022   220520034
# 3       2023  1152946903

# %%
import pandas as pd
import matplotlib.pyplot as plt

db = pd.read_csv('./database/jobs-and-salaries-in-data-science/jobs_in_data.csv')

tabela_resumida = db.groupby('work_year')['salary'].sum().reset_index()

plt.bar(tabela_resumida.work_year, tabela_resumida.salary)

print(tabela_resumida)

plt.show()
# Out:
#    work_year      salary
# 0       2020     7577809
# 1       2021    21531519
# 2       2022   220520034
# 3       2023  1152946903
